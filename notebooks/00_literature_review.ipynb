# %% [markdown]
# # 00 — Literature Review
#
# **Maps to:** `report/Chapters/LiteratureReview.tex` (label `SecLiteratureReview`).
# **Ticket:** TICKET-22.
# **Purpose:** working surface for collecting and summarising citations. Final prose lands in the `.tex` file. New BibTeX entries get appended to `report/Bibliography.bib`.
#
# Target: ≥10 academic citations.
#
# ## How to use this notebook
# 1. Add a one-paragraph summary of each paper under the correct theme.
# 2. Drop the BibTeX entry into `report/Bibliography.bib`.
# 3. Once a theme has ≥3 sources, draft the corresponding subsection in `LiteratureReview.tex`.

# %% [markdown]
# ## Genetic Algorithms for the TSP
# Maps to `Lit:GAforTSP` in `LiteratureReview.tex`.
#
# - TODO: foundational GA-for-TSP references (Goldberg 1989; Larrañaga 1999 survey).
# - TODO: more recent benchmark studies.

# %% [markdown]
# ## Constraint Handling in Evolutionary Algorithms
# Maps to `Lit:ConstraintHandling`.
#
# - TODO: Coello (2002) survey; Michalewicz & Schoenauer (1996).

# %% [markdown]
# ## Repair Mechanisms in Permutation-based EAs
# Maps to `Lit:Repair`.
#
# - TODO: repair vs. penalty trade-offs; references comparing duplicate-removal strategies.

# %% [markdown]
# ## Comparison Studies of Crossover Operators (PMX/OX/CX)
# Supports `T2:Crossover` in `Task2.tex`.
#
# - TODO: empirical comparisons relevant to chosen instance size (70–150 cities).
