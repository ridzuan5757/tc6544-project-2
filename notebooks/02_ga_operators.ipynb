# %% [markdown]
# # 02 — Genetic Algorithm Operators
#
# **Maps to:** `report/Chapters/Task2.tex` §`T2:GADesign` (Task 2.1).
# **Tickets:** TICKET-05, 06, 07, 08, 09, 10.
#
# Each section demos an operator from `src/ga/` on a toy 5–10 city instance, then validates on the full benchmark. Final prose + figures land in `Task2.tex` §`T2:GADesign`.

# %%
# from ga import chromosome, init_pop, selection, crossover, mutation, loop
# from ga.instance import load_tsp

# %% [markdown]
# ## Representation and Fitness — TICKET-05
# Maps to `T2:Representation`. Code: `src/ga/chromosome.py`.
#
# - permutation encoding;
# - `tour_length(chromosome, dist_matrix)` for fitness;
# - `is_valid_permutation` for invariants.

# %% [markdown]
# ## Population Initialisation — TICKET-06
# Maps to `T2:Init`. Code: `src/ga/init_pop.py`. Random vs. nearest-neighbour-seeded vs. hybrid.

# %% [markdown]
# ## Selection — TICKET-07
# Maps to `T2:Selection`. Code: `src/ga/selection.py`. Tournament (vary $k$) and roulette wheel. Show selection pressure on a toy fitness vector.

# %% [markdown]
# ## Crossover — TICKET-08 (risk point: allocate full week)
# Maps to `T2:Crossover`. Code: `src/ga/crossover.py`. Implement PMX, OX, CX. For each, show:
# - worked example on a 5-city toy with a fixed cut/segment;
# - whether the operator can produce infeasible offspring (feeds TICKET-11 in notebook 03).

# %% [markdown]
# ## Mutation — TICKET-09
# Maps to `T2:Mutation`. Code: `src/ga/mutation.py`. Swap and inversion; sweep mutation rate.

# %% [markdown]
# ## Main GA Loop — TICKET-10
# Code: `src/ga/loop.py`. Wires selection → crossover → mutation → repair, returns a run record (per-gen best/mean fitness, diversity, final tour). Smoke-test with population=50, generations=200.
