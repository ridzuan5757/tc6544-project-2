# %% [markdown]
# # 03 — Repair Mechanism (Graded Focus)
#
# **Maps to:** `report/Chapters/Task2.tex` §`T2:Repair` (Task 2.2) **and** `report/Chapters/Task3.tex` §`T3:RepairCritique` (Task 3.3).
# **Tickets:** TICKET-11 (theory), TICKET-12 (impl, graded), TICKET-13 (alternative), TICKET-14 (diversity), TICKET-21 (writeup).
#
# This notebook is the centre of gravity for the grade. Worked examples here → prose + figures in the two report sections above.

# %% [markdown]
# ## Sources of Infeasibility — TICKET-11
# Maps to `T2:Infeasibility`.
#
# For each crossover operator (PMX/OX/CX), produce a worked toy example showing whether and how the permutation property breaks. Pure-prose ticket; this notebook just hosts the examples that the prose references.

# %%
# from ga import crossover
# from repair.repair import repair

# %% [markdown]
# ## Repair Design — TICKET-12 (graded focus)
# Maps to `T2:RepairDesign`. Code: `src/repair/repair.py`.
#
# Step-by-step:
# 1. scan, mark first occurrence of each city;
# 2. flag duplicates;
# 3. identify missing cities;
# 4. replace duplicates with missing — three insertion variants: random / position-based / nearest-neighbour.
#
# Show repair on:
# - no-duplicate input (identity);
# - single duplicate;
# - multiple duplicates;
# - edge cases (all-same, reversed).

# %% [markdown]
# ## Alternative Constraint Handling — TICKET-13
# Code: `src/repair/alternative.py`. Implement at least one of: penalty function, feasibility-preserving operator. Pick penalty if behind schedule (fastest).
#
# Used by `experiments/compare.py` (TICKET-17).

# %% [markdown]
# ## Diversity Instrumentation — TICKET-14
# Maps to `T2:RepairEffect` (and feeds Task 3 critique). Code: `src/ga/diversity.py`.
#
# Pairwise Hamming + edge-overlap on the population each generation. Verify on a known-collapsed population (all identical → diversity 0).

# %% [markdown]
# ## Critical Analysis Writeup — TICKET-21
# Maps to `T3:RepairCritique`. This is where empirical results from notebook 04 get interpreted:
# - effectiveness of repair (does it converge faster / to better tours?);
# - trade-off between feasibility enforcement and exploration (diversity timeseries);
# - repair vs. alternative (penalty / feasibility-preserving).
#
# Final prose lives in `Task3.tex` §`T3:RepairCritique`. Figures referenced from notebook 05.
