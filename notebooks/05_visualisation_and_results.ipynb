# %% [markdown]
# # 05 — Visualisation and Results
#
# **Maps to:** `report/Chapters/Task4.tex` (all subsections).
# **Tickets:** TICKET-18 (convergence), TICKET-19 (boxplots), TICKET-20 (best-tour, optional).
#
# Every figure produced here is saved into `results/figures/` and `\includegraphics`-d from `Task4.tex`.

# %%
# import pandas as pd, matplotlib.pyplot as plt
# sweep = pd.read_csv('../results/sweep.csv')
# compare = pd.read_csv('../results/compare.csv')

# %% [markdown]
# ## Convergence Curves — TICKET-18
# Maps to `T4:Convergence`. Best-so-far and population-mean fitness vs. generation, averaged across runs with 95% CI band. Output: `results/figures/convergence_<config>.pdf`.

# %% [markdown]
# ## Solution-Quality Boxplots — TICKET-19
# Maps to `T4:Boxplots`. Final tour length per configuration / per constraint-handling strategy. Output: `results/figures/boxplot_<axis>.pdf`.

# %% [markdown]
# ## Best-Tour Visualisation — TICKET-20 (optional)
# Maps to `T4:BestTour`. 2D scatter + edges of the best tour; optional per brief — first scope cut if behind.

# %% [markdown]
# ## Results Discussion
# Maps to `T4:Discussion`. Interpret the figures, tie back to `T3:RepairCritique`. Final prose in `Task4.tex`.
