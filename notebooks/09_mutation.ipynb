# %% [markdown]
# # 09 — Mutation Operators (Swap and Inversion)
#
# **Maps to:** `report/Chapters/Task2.tex` §`T2:Mutation`.
# **Ticket:** TICKET-09.
#
# Swap and inversion; sweep mutation rate.

# %%
import numpy as np


def swap_mutation(chromosome, rate, rng):
    raise NotImplementedError


def inversion_mutation(chromosome, rate, rng):
    raise NotImplementedError
