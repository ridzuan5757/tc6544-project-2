# %% [markdown]
# # 09 — Mutation Operators (Swap and Inversion)
#
# **Maps to:** `report/Chapters/Task2.tex` §`T2:Mutation`.
# **Ticket:** TICKET-09.
#
# Code: `src/ga/mutation.py`. Swap and inversion; sweep mutation rate.

# %%
# from ga.mutation import swap_mutation, inversion_mutation
